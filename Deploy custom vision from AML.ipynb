# %%
import numpy as np
import os
from azureml.core import Workspace, Experiment
from azureml.core.model import InferenceConfig,Model
from azureml.core.webservice import LocalWebservice,AciWebservice

import azureml

# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.0.57

# %%
# ENter credentials of workspace

subscription_id = ""
resource_group = ""
workspace_name = ""

ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
print(ws.name, ws.location, ws.resource_group, ws.location, sep = '\t')
# Out:
# repro	westeurope	adb_rg	westeurope

# %%
# Get an experiment object from Azure Machine Learning
experiment = Experiment(workspace=ws, name="custom_vision")

# Create a run object in the experiment
run = experiment.start_logging()

# %%
run.upload_folder(path='./model', name="model")

# %%
run
# Out:
# Run(Experiment: custom_vision,
# Id: 419a0ee4-26c5-47a2-ab7b-5ee3ae34a48e,
# Type: None,
# Status: Running)

# %%
model = run.register_model(model_name='model', model_path='model')

# %%
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core.image import ContainerImage

env = CondaDependencies()

env.add_pip_package("numpy")
env.add_pip_package("tensorflow")
env.add_pip_package("pillow")

# Write the environment to disk
with open("env.yml","w") as f:
    f.write(env.serialize_to_string())

# %%
inference_config = InferenceConfig(source_directory=os.path.join(os.getcwd(),"score"),
                                   runtime= "python",
                                   entry_script="score.py",
                                   conda_file=os.path.join(os.getcwd(),"env.yml")
                                  )

# %% [markdown]
# ## REPLACE LocalWebService with AciWebService
# https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-deploy-and-where#deploy-to-target

# %%
deployment_config = LocalWebservice.deploy_configuration(port=8877)
service = Model.deploy(ws, "customvisionpro", [model], inference_config, deployment_config)
service.wait_for_deployment(show_output = False)
print(service.state)
# Out:
# Downloading model model:1 to /tmp/azureml_ci8rynzt/model/1
# Generating Docker build context.
# 2019/09/11 11:17:02 Downloading source code...
# 2019/09/11 11:17:04 Finished downloading source code
# 2019/09/11 11:17:05 Using acb_vol_99d101fc-ec6c-4a0b-8a47-bbfe6db5e64f as the home volume
# 2019/09/11 11:17:05 Creating Docker network: acb_default_network, driver: 'bridge'
# 2019/09/11 11:17:05 Successfully set up Docker network: acb_default_network
# 2019/09/11 11:17:05 Setting up Docker configuration...
# 2019/09/11 11:17:06 Successfully set up Docker configuration
# 2019/09/11 11:17:06 Logging in to registry: repro7727500668.azurecr.io
# 2019/09/11 11:17:17 Successfully logged into repro7727500668.azurecr.io
# 2019/09/11 11:17:17 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2019/09/11 11:17:17 Scanning for dependencies...
# 2019/09/11 11:17:18 Successfully scanned dependencies
# 2019/09/11 11:17:18 Launching container with name: acb_step_0
# Sending build context to Docker daemon  59.39kB
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:1cb0b2b66b32c44c0e63ef929f66c4fc9df1cc7a35a068000e53c168609180eb
# sha256:1cb0b2b66b32c44c0e63ef929f66c4fc9df1cc7a35a068000e53c168609180eb: Pulling from azureml/base
# f7277927d38a: Already exists
# 8d3eac894db4: Already exists
# edf72af6d627: Already exists
# 3e4f86211d23: Already exists
# 0cba86f42f6f: Pulling fs layer
# 7f00346ddc0c: Pulling fs layer
# 2bbda679fd17: Pulling fs layer
# c4bb3cdfad8e: Pulling fs layer
# 585221edb64b: Pulling fs layer
# df4ef0bad62e: Pulling fs layer
# 1e878e83b4c4: Pulling fs layer
# c4bb3cdfad8e: Waiting
# 585221edb64b: Waiting
# df4ef0bad62e: Waiting
# 1e878e83b4c4: Waiting
# 7f00346ddc0c: Verifying Checksum
# 7f00346ddc0c: Download complete
# 2bbda679fd17: Verifying Checksum
# 2bbda679fd17: Download complete
# 0cba86f42f6f: Verifying Checksum
# 0cba86f42f6f: Download complete
# c4bb3cdfad8e: Verifying Checksum
# c4bb3cdfad8e: Download complete
# 1e878e83b4c4: Verifying Checksum
# 1e878e83b4c4: Download complete
# 585221edb64b: Verifying Checksum
# 585221edb64b: Download complete
# df4ef0bad62e: Verifying Checksum
# df4ef0bad62e: Download complete
# 0cba86f42f6f: Pull complete
# 7f00346ddc0c: Pull complete
# 2bbda679fd17: Pull complete
# c4bb3cdfad8e: Pull complete
# 585221edb64b: Pull complete
# df4ef0bad62e: Pull complete
# 1e878e83b4c4: Pull complete
# Digest: sha256:1cb0b2b66b32c44c0e63ef929f66c4fc9df1cc7a35a068000e53c168609180eb
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:1cb0b2b66b32c44c0e63ef929f66c4fc9df1cc7a35a068000e53c168609180eb
#  ---> b41a9ddf5713
# Step 2/15 : USER root
#  ---> Running in 15e5bb5d82c6
# Removing intermediate container 15e5bb5d82c6
#  ---> a6693a49d3d1
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 7e2705e179f8
# Removing intermediate container 7e2705e179f8
#  ---> 8bcc0f65be3c
# Step 4/15 : WORKDIR /
#  ---> Running in 900e5ea53b6b
# Removing intermediate container 900e5ea53b6b
#  ---> 3d5363e30c6b
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 9569d237c793
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 816894a01e45
# Removing intermediate container 816894a01e45
#  ---> 21047853b7d6
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 3cfe81c405c3
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 9554bce25fc6
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# openssl-1.0.2r       | 3.1 MB    | ########## | 100%
# xz-5.2.4             | 366 KB    | ########## | 100%
# python-3.6.2         | 19.0 MB   | ########## | 100%
# wheel-0.33.6         | 35 KB     | ########## | 100%
# pip-19.2.3           | 1.9 MB    | ########## | 100%
# zlib-1.2.11          | 105 KB    | ########## | 100%
# ca-certificates-2019 | 145 KB    | ########## | 100%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# setuptools-41.2.0    | 634 KB    | ########## | 100%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
# readline-6.2         | 713 KB    | ########## | 100%
# certifi-2019.6.16    | 149 KB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults (from -r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/1a/ce/56f11748a617ce0bdb83caef55514331d60c91526a13121ce42d56a28c5a/azureml_defaults-1.0.60-py2.py3-none-any.whl
# Collecting numpy (from -r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/e5/e6/c3fdc53aed9fa19d6ff3abf97dfad768ae3afce1b7431f7500000816bda5/numpy-1.17.2-cp36-cp36m-manylinux1_x86_64.whl (20.4MB)
# Collecting tensorflow (from -r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
# Collecting pillow (from -r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/14/41/db6dec65ddbc176a59b89485e8cc136a433ed9c6397b6bfe2cd38412051e/Pillow-6.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
# Collecting configparser==3.7.4 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ba/05/6c96328e92e625fc31445d24d75a2c92ef9ba34fc5b037fe69693c362a0d/configparser-3.7.4-py2.py3-none-any.whl
# Collecting json-logging-py==0.2 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e9/e1/46c70eebf216b830867c4896ee678cb7f1b28bb68a2810c7e9a811cecfbc/json-logging-py-0.2.tar.gz
# Collecting gunicorn==19.9.0 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/8c/da/b8dd8deb741bff556db53902d4706774c8e1e67265f69528c14c003644e6/gunicorn-19.9.0-py2.py3-none-any.whl (112kB)
# Collecting azureml-core==1.0.60.* (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ad/2b/7da52c5138413a316468e626cfbd1157eafa85461333cc12508f216a5e4f/azureml_core-1.0.60-py2.py3-none-any.whl (1.1MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4e/53/9004a1e7d6d4e796abc4bcc8286bfc2a32739c5fbac3859ca7429a228897/azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130kB)
# Collecting flask==1.0.3 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9a/74/670ae9737d14114753b8c8fdf2e8bd212a05d3b361ab15b44937dfd40985/Flask-1.0.3-py2.py3-none-any.whl (92kB)
# Collecting applicationinsights>=0.11.7 (from azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/53/234c53004f71f0717d8acd37876e0b65c121181167057b9ce1b1795f96a0/applicationinsights-0.11.9-py2.py3-none-any.whl (58kB)
# Collecting absl-py>=0.7.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/3c/0d/7cbf64cac3f93617a2b6b079c0182e4a83a3e7a8964d3b0cc3d9758ba002/absl-py-0.8.0.tar.gz (102kB)
# Collecting six>=1.10.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting wrapt>=1.11.1 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Collecting gast>=0.2.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/4d/17/a92e707853e2fb48aea76dcdc200ea9a2f7d1ce6d1eff07ddfcf326184cb/gast-0.3.1.tar.gz
# Collecting termcolor>=1.1.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Requirement already satisfied: wheel>=0.26 in /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/python3.6/site-packages (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3)) (0.33.6)
# Collecting astor>=0.6.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting protobuf>=3.6.1 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/eb/f4/a27952733796330cd17c17ea1f974459f5fefbbad119c0f296a6d807fec3/protobuf-3.9.1-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
# Collecting keras-applications>=1.0.6 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
# Collecting tensorboard<1.15.0,>=1.14.0 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
# Collecting grpcio>=1.8.6 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/30/31/6397193572c081e0fd1fec86a7a6b7ac497c27226281e7cb32f8c3705069/grpcio-1.23.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
# Collecting google-pasta>=0.1.6 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
# Collecting keras-preprocessing>=1.0.5 (from tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
# Collecting pathspec (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting backports.tempfile (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/00/55/a703923c12cd3172d5c007beda0c1a34342a17a6a72779f8a7c269af0cd6/azure_common-1.1.23-py2.py3-none-any.whl
# Collecting adal>=1.2.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4f/b5/3ea9ae3d1096b9ff31e8f1846c47d49f3129a12464ac0a73b602de458298/adal-1.2.2-py2.py3-none-any.whl (53kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b3/d1/9fed0a3a3b43d0b1ad59599b5c836ccc4cf117e26458075385bafe79575b/azure_mgmt_keyvault-2.0.0-py2.py3-none-any.whl (80kB)
# Collecting msrest>=0.5.1 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/b0/c34b3ea9b2ed74b800520fbefb312cdb7f05c20b8bd42e5e7662a5614f98/msrest-0.6.10-py2.py3-none-any.whl (82kB)
# Collecting jmespath (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
# Collecting pyopenssl (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
# Collecting PyJWT (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/3e/93/02056aca45162f9fc275d1eaad12a2a07ef92375afb48eabddc4134b8315/azure_graphrbac-0.61.1-py2.py3-none-any.whl (141kB)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/8c/03/62c3ed229b9b83fbf4dcd56ae27d5d835f3bd921004c09a478729c221fff/azure_mgmt_storage-4.0.0-py2.py3-none-any.whl (426kB)
# Collecting requests>=2.19.1 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
# Collecting docker (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/95/47/5560c9cf0c92b50da24216f0e7733250fbed5a497f69e3c70e1be62143fe/docker-4.0.2-py2.py3-none-any.whl (138kB)
# Collecting urllib3>=1.23 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/60/247f23a7121ae632d62811ba7f273d0e58972d75e58a94d329d51550a47d/urllib3-1.25.3-py2.py3-none-any.whl (150kB)
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/97/70/8c2d0509db466678eba16fa2b0a539499f3b351b1f2993126ad843d5be13/azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718kB)
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f9/34/e29f97d24f55d6f0a70186acf5b0b3e7f9d87a444f08ad7d758020d5777f/azure_mgmt_resource-4.0.0-py2.py3-none-any.whl (657kB)
# Collecting contextlib2 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting ndg-httpsclient (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0a/aa/b17a4f702ecd6d9e989ae34109aa384c988aed0de37215c651165ed45238/msrestazure-0.6.1-py2.py3-none-any.whl (40kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/36/e1/cc2fa400fa5ffde3efa834ceb15c464075586de05ca3c553753dcd6f1d3b/ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651kB)
# Collecting SecretStorage (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/82/59/cb226752e20d83598d7fdcabd7819570b0329a61db07cfbdd21b2ef546e3/SecretStorage-3.1.1-py3-none-any.whl
# Collecting python-dateutil>=2.7.3 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5e/17/4724694ddb3311955ddc367eddcd0928f8ee2c7b12d5a6f0b12bca0b03db/azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82kB)
# Collecting pytz (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/76/46d697698a143e05f77bec5a526bf4e56a0be61d63425b68f4ba553b51f2/pytz-2019.2-py2.py3-none-any.whl (508kB)
# Collecting jsonpickle (from azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/07/07/c157520a3ebd166c8c24c6ae0ecae7c3968eb4653ff0e5af369bb82f004d/jsonpickle-1.2-py2.py3-none-any.whl
# Collecting liac-arff>=2.1.1 (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e9/35/fbc9217cfa91d98888b43e1a19c03a50d716108c58494c558c65e308f372/liac-arff-2.4.0.tar.gz
# Collecting pandas>=0.20.2 (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/73/9b/52e228545d14f14bb2a1622e225f38463c8726645165e1cb7dde95bfe6d4/pandas-0.25.1-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
# Collecting dill>=0.2.7.1 (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/39/7a/70803635c850e351257029089d38748516a280864c97cbc73087afef6d51/dill-0.3.0.tar.gz (151kB)
# Collecting Jinja2>=2.10 (from flask==1.0.3->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl (124kB)
# Collecting click>=5.1 (from flask==1.0.3->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
# Collecting Werkzeug>=0.14 (from flask==1.0.3->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/61/c0a1adf9ad80db012ed7191af98fa05faa95fa09eceb71bb6fa8b66e6a43/Werkzeug-0.15.6-py2.py3-none-any.whl (328kB)
# Collecting itsdangerous>=0.24 (from flask==1.0.3->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3)) (41.2.0)
# Collecting h5py (from keras-applications>=1.0.6->tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/60/06/cafdd44889200e5438b897388f3075b52a8ef01f28a17366d91de0fa2d05/h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9MB)
# Collecting markdown>=2.6.8 (from tensorboard<1.15.0,>=1.14.0->tensorflow->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1)) (2019.6.16)
# Collecting cffi!=1.11.3,>=1.8 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5f/bf/6aa1925384c23ffeb579e97a5569eb9abce41b6310b329352b8252cee1c3/cffi-1.12.3-cp36-cp36m-manylinux1_x86_64.whl (430kB)
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting idna<2.9,>=2.5 (from requests>=2.19.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl (200kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/71/8f0d444e3a74e5640a3d5d967c1c6b015da9c655f35b2d308a55d907a517/pyasn1-0.4.7-py2.py3-none-any.whl (76kB)
# Collecting jeepney (from SecretStorage->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0a/4c/ef880713a6c6d628869596703167eab2edf8e0ec2d870d1089dcb0901b81/jeepney-0.4.1-py3-none-any.whl (60kB)
# Collecting MarkupSafe>=0.23 (from Jinja2>=2.10->flask==1.0.3->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.60.*->azureml-defaults->-r /azureml-environment-setup/condaenv.mfp4zswl.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Building wheels for collected packages: json-logging-py, absl-py, wrapt, gast, termcolor, pathspec, liac-arff, dill, pycparser
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-cp36-none-any.whl size=3924 sha256=6a704a3c87c10a86327dfb3ae592db522c355b81f8bff5c250d0c2bdbb7bc47a
#   Stored in directory: /root/.cache/pip/wheels/0d/2e/1c/c638b7589610d8b9358a6e5eb008edacb8b3e9b6d1edc9479f
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.8.0-cp36-none-any.whl size=120987 sha256=56a72d7090d4a428ec7cfad409044cc2ff82f54bdd676f104f7458f6130ed142
#   Stored in directory: /root/.cache/pip/wheels/9a/1e/7a/456008eb5e47fd5de792c6139df6d5b3d5f71d51c6a0b94799
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp36-cp36m-linux_x86_64.whl size=66319 sha256=1a6f00942e2c8e3e5d23ab5455a1c7b001adec384eae89359dbe8655c31eaaa0
#   Stored in directory: /root/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.3.1-cp36-none-any.whl size=9289 sha256=956e7274f88d5d3601d6bbea3bfab9d5f4f07fa7095fcc7b37e37fdf8c909485
#   Stored in directory: /root/.cache/pip/wheels/d0/e8/de/cf6666d48241d10e5d7cd53fb3b5e447ea8e659f767d669b11
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp36-none-any.whl size=4832 sha256=be769780edb4d044fe9c83ebba7dac685a10b38be4f3bb2f0fe585a6bab8be53
#   Stored in directory: /root/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for pathspec (setup.py): started
#   Building wheel for pathspec (setup.py): finished with status 'done'
#   Created wheel for pathspec: filename=pathspec-0.5.9-cp36-none-any.whl size=26357 sha256=e6a981a08bb32e1bef0f1b4835a6ae647cc43fecb82289ec83290b1cc591cad0
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-cp36-none-any.whl size=13333 sha256=8a55529d5b7aaaba6ed119946e7162cd3b69b161b2269e0fa3324f65b78c792d
#   Stored in directory: /root/.cache/pip/wheels/d1/6a/e7/529dc54d76ecede4346164a09ae3168df358945612710f5203
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.0-cp36-none-any.whl size=77513 sha256=0b149bb901e7f6e4f1d1aec3b2c8784ad7c690aff37bf9b2e673cd11ddfcfd96
#   Stored in directory: /root/.cache/pip/wheels/c9/de/a4/a91eec4eea652104d8c81b633f32ead5eb57d1b294eab24167
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Created wheel for pycparser: filename=pycparser-2.19-py2.py3-none-any.whl size=111029 sha256=8d40a89f1e083b5a93d840027c676c7d717b16111240e7d9ce0905dcfb3724c6
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built json-logging-py absl-py wrapt gast termcolor pathspec liac-arff dill pycparser
# Installing collected packages: configparser, json-logging-py, gunicorn, pathspec, backports.weakref, backports.tempfile, azure-common, PyJWT, urllib3, idna, chardet, requests, six, pycparser, cffi, asn1crypto, cryptography, python-dateutil, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-mgmt-keyvault, jmespath, pyopenssl, azure-graphrbac, azure-mgmt-storage, websocket-client, docker, azure-mgmt-containerregistry, azure-mgmt-resource, contextlib2, pyasn1, ndg-httpsclient, ruamel.yaml, jeepney, SecretStorage, azure-mgmt-authorization, pytz, jsonpickle, azureml-core, liac-arff, numpy, pandas, dill, azureml-model-management-sdk, MarkupSafe, Jinja2, click, Werkzeug, itsdangerous, flask, applicationinsights, azureml-defaults, absl-py, wrapt, gast, termcolor, astor, protobuf, h5py, keras-applications, tensorflow-estimator, grpcio, markdown, tensorboard, google-pasta, keras-preprocessing, tensorflow, pillow
# Successfully installed Jinja2-2.10.1 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.1 Werkzeug-0.15.6 absl-py-0.8.0 adal-1.2.2 applicationinsights-0.11.9 asn1crypto-0.24.0 astor-0.8.0 azure-common-1.1.23 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.0.0 azure-mgmt-resource-4.0.0 azure-mgmt-storage-4.0.0 azureml-core-1.0.60 azureml-defaults-1.0.60 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.12.3 chardet-3.0.4 click-7.0 configparser-3.7.4 contextlib2-0.5.5 cryptography-2.7 dill-0.3.0 docker-4.0.2 flask-1.0.3 gast-0.3.1 google-pasta-0.1.7 grpcio-1.23.0 gunicorn-19.9.0 h5py-2.10.0 idna-2.8 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.1 jmespath-0.9.4 json-logging-py-0.2 jsonpickle-1.2 keras-applications-1.0.8 keras-preprocessing-1.1.0 liac-arff-2.4.0 markdown-3.1.1 msrest-0.6.10 msrestazure-0.6.1 ndg-httpsclient-0.5.1 numpy-1.17.2 oauthlib-3.1.0 pandas-0.25.1 pathspec-0.5.9 pillow-6.1.0 protobuf-3.9.1 pyasn1-0.4.7 pycparser-2.19 pyopenssl-19.0.0 python-dateutil-2.8.0 pytz-2019.2 requests-2.22.0 requests-oauthlib-1.2.0 ruamel.yaml-0.15.89 six-1.12.0 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 termcolor-1.1.0 urllib3-1.25.3 websocket-client-0.56.0 wrapt-1.11.2
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container 9554bce25fc6
#  ---> e4301d98ea24
# Step 9/15 : ENV PATH /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/bin:$PATH
#  ---> Running in c5c4e56a9899
# Removing intermediate container c5c4e56a9899
#  ---> db870226f4c7
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009
#  ---> Running in 011d8326b293
# Removing intermediate container 011d8326b293
#  ---> 665a932a295d
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib:$LD_LIBRARY_PATH
#  ---> Running in 8c43cc5df775
# Removing intermediate container 8c43cc5df775
#  ---> a8097a6a3538
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 8ac1e73eb844
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 5c4988b73b3f
# Removing intermediate container 5c4988b73b3f
#  ---> 0768e17bfc9e
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in b8b65841078d
# Removing intermediate container b8b65841078d
#  ---> 14dd34c8faac
# Step 15/15 : CMD ["bash"]
#  ---> Running in 56e5afd28518
# Removing intermediate container 56e5afd28518
#  ---> 9f10bfd2278f
# Successfully built 9f10bfd2278f
# Successfully tagged repro7727500668.azurecr.io/azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248:latest
# 2019/09/11 11:20:24 Successfully executed container: acb_step_0
# 2019/09/11 11:20:24 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2019/09/11 11:20:24 Pushing image: repro7727500668.azurecr.io/azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248:latest, attempt 1
# The push refers to repository [repro7727500668.azurecr.io/azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248]
# 8795bb542cd9: Preparing
# bb151bd26c48: Preparing
# 06b94f1cae18: Preparing
# bcba729f85b2: Preparing
# 804c9465c0c9: Preparing
# fcace60d37a2: Preparing
# fbff9364eca2: Preparing
# aa1089a38fc5: Preparing
# 10d9ac6f4aca: Preparing
# dc21a43165bf: Preparing
# db2f1de47d6e: Preparing
# 91d2053074e1: Preparing
# 60b94bb60254: Preparing
# e79142719515: Preparing
# aeda103e78c9: Preparing
# 2558e637fbff: Preparing
# f749b9b0fb21: Preparing
# dc21a43165bf: Waiting
# db2f1de47d6e: Waiting
# 91d2053074e1: Waiting
# 60b94bb60254: Waiting
# e79142719515: Waiting
# aeda103e78c9: Waiting
# 2558e637fbff: Waiting
# f749b9b0fb21: Waiting
# aa1089a38fc5: Waiting
# 10d9ac6f4aca: Waiting
# fcace60d37a2: Waiting
# fbff9364eca2: Waiting
# 804c9465c0c9: Pushed
# 06b94f1cae18: Pushed
# 8795bb542cd9: Pushed
# bcba729f85b2: Pushed
# fcace60d37a2: Pushed
# fbff9364eca2: Pushed
# aa1089a38fc5: Pushed
# db2f1de47d6e: Pushed
# 91d2053074e1: Pushed
# 10d9ac6f4aca: Pushed
# e79142719515: Pushed
# 2558e637fbff: Pushed
# dc21a43165bf: Pushed
# aeda103e78c9: Pushed
# f749b9b0fb21: Pushed
# 60b94bb60254: Pushed
# bb151bd26c48: Pushed
# latest: digest: sha256:2543d26ee10fe07dbccef9eb31d06a81c64f16884127f7d7f4850880318c5e3e size: 3883
# 2019/09/11 11:22:07 Successfully pushed image: repro7727500668.azurecr.io/azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248:latest
# 2019/09/11 11:22:07 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 186.732187)
# 2019/09/11 11:22:07 Populating digests for step ID: acb_step_0...
# 2019/09/11 11:22:09 Successfully populated digests for step ID: acb_step_0
# 2019/09/11 11:22:09 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 103.252750)
# 2019/09/11 11:22:09 The following dependencies were found:
# 2019/09/11 11:22:09
# - image:
#     registry: repro7727500668.azurecr.io
#     repository: azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248
#     tag: latest
#     digest: sha256:2543d26ee10fe07dbccef9eb31d06a81c64f16884127f7d7f4850880318c5e3e
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:1cb0b2b66b32c44c0e63ef929f66c4fc9df1cc7a35a068000e53c168609180eb
#   git: {}
#
#
# Run ID: cb49 was successful after 5m8s
# Package creation Succeeded
# Logging into Docker registry repro7727500668.azurecr.io
# Building Docker image from Dockerfile...
# Step 1/5 : FROM repro7727500668.azurecr.io/azureml/azureml_749bcd2b7e343aa3e6da61be0b1a2248
#  ---> 9f10bfd2278f
# Step 2/5 : COPY azureml-app /var/azureml-app
#  ---> e62fda58d564
# Step 3/5 : COPY model_config_map.json /var/azureml-app/model_config_map.json
#  ---> 8b9b6ac5b8a8
# Step 4/5 : RUN mv '/var/azureml-app/tmpz81ql3ba.py' /var/azureml-app/main.py
#  ---> Running in 47f6522a2fd8
#  ---> d339630b33fb
# Step 5/5 : CMD ["runsvdir","/var/runit"]
#  ---> Running in a1942fef55b1
#  ---> e024324bd00d
# Successfully built e024324bd00d
# Successfully tagged customvisionpro:latest
# Starting Docker container...
# Docker container running.
# Checking container health...
# Local webservice is running at http://localhost:8877
# running

# %%
service.get_logs()
# Out:
# '/bin/bash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by /bin/bash)\n/bin/bash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by /bin/bash)\n/bin/bash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by /bin/bash)\n/bin/bash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by /bin/bash)\n2019-09-11T11:23:15,605842668+00:00 - iot-server/run \n2019-09-11T11:23:15,605872368+00:00 - gunicorn/run \n2019-09-11T11:23:15,606007669+00:00 - rsyslog/run \nbash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by bash)\n2019-09-11T11:23:15,607371477+00:00 - nginx/run \n/usr/sbin/nginx: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)\n/usr/sbin/nginx: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)\n/usr/sbin/nginx: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)\n/usr/sbin/nginx: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)\n/usr/sbin/nginx: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)\nEdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...\n/bin/bash: /azureml-envs/azureml_007b1ffbf70e414fdc48e005caeca009/lib/libtinfo.so.5: no version information available (required by /bin/bash)\n2019-09-11T11:23:15,673315390+00:00 - iot-server/finish 1 0\n2019-09-11T11:23:15,674373696+00:00 - Exit code 1 is normal. Not restarting iot-server.\nStarting gunicorn 19.9.0\nListening at: http://127.0.0.1:31311 (12)\nUsing worker: sync\nworker timeout is set to 300\nBooting worker with pid: 50\nFrom ./score/predict.py:20: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.\n\nInitializing logger\nStarting up app insights client\nStarting up request id generator\nStarting up app insight hooks\nInvoking user\'s init function\n2019-09-11 11:23:18,076 | azureml.core.run | DEBUG | Could not load run context RunEnvironmentException:\n\tMessage: Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run.\n\tInnerException None\n\tErrorResponse \n{\n    "error": {\n        "message": "Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run."\n    }\n}, switching offline: False\n2019-09-11 11:23:18,076 | azureml.core.run | DEBUG | Could not load the run context and allow_offline set to False\n2019-09-11 11:23:18,077 | azureml.core.model | DEBUG | RunEnvironmentException: RunEnvironmentException:\n\tMessage: Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run.\n\tInnerException RunEnvironmentException:\n\tMessage: Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run.\n\tInnerException None\n\tErrorResponse \n{\n    "error": {\n        "message": "Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run."\n    }\n}\n\tErrorResponse \n{\n    "error": {\n        "message": "Could not load a submitted run, if outside of an execution context, use experiment.start_logging to initialize an azureml.core.Run."\n    }\n}\n2019-09-11 11:23:18,077 | azureml.core ...

# %%
# !wget https://raw.githubusercontent.com/Microsoft/Cognitive-CustomVision-Windows/master/Samples/Images/Test/test_image.jpg
# Out:
# --2019-09-11 11:26:16--  https://raw.githubusercontent.com/Microsoft/Cognitive-CustomVision-Windows/master/Samples/Images/Test/test_image.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.36.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.36.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86514 (84K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]  84.49K  --.-KB/s    in 0.01s
#
# 2019-09-11 11:26:17 (7.48 MB/s) - ‘test_image.jpg’ saved [86514/86514]

# %%
import PIL
from PIL import Image
import numpy as np

import base64
import io
import json


image = Image.open("test_image.jpg")
imgio = io.BytesIO()
image.save(imgio, "PNG")
imgio.seek(0)
dataimg = base64.b64encode(imgio.read())
prediction_input = '{"image": "' + dataimg.decode('utf-8') + '"}'

# %%
service.run(prediction_input)
# Out:
# Making a scoring call...
# Scoring result:
# {'id': '', 'project': '', 'iteration': '', 'created': '2019-09-11T11:27:58.001647', 'predictions': [{'tagName': 'Titile_Front_CA', 'probability': 0.00014463000115938485, 'tagId': '', 'boundingBox': None}, {'tagName': 'Title_Front_IN', 'probability': 0.9998553395271301, 'tagId': '', 'boundingBox': None}]}
